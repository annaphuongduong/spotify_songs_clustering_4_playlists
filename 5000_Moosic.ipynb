# %% [markdown]
# <a href="https://colab.research.google.com/github/annaphuongduong/spotify_songs_clustering_4_playlists/blob/main/5000_Moosic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-33d9a45d-b64c-42aa-8605-60d587769de7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-33d9a45d-b64c-42aa-8605-60d587769de7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import io
df = pd.read_csv(io.BytesIO(uploaded['3_spotify_5000_songs.csv']))

# %%
print(df)
# Out:
#       Unnamed: 0  \
# 0              0
# 1              1
# 2              2
# 3              3
# 4              4
# ...          ...
# 5230        5230
# 5231        5231
# 5232        5232
# 5233        5233
# 5234        5234
#
#      name                                                                                                                                                                               \
# 0     Se Eu Quiser Falar Com Deus                   ...
# 1     Saudade De Bahia                              ...
# 2     Canta Canta, Minha Gente                      ...
# 3     Mulher Eu Sei                                 ...
# 4     Rosa Morena                                   ...
# ...                                                 ...
# 5230  1812 Festival Overture, Op. 49: 1812 Overture,...
# 5231  Winter Fragments pour ensemble instrumental, s...
# 5232  Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3...
# ...

# %% [markdown]
# ### link for sklearn documentation: https://scikit-learn.org/stable/

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df_copied = pd.DataFrame.copy(df)

data_df = pd.DataFrame(df_copied)
data_df.dtypes
# Out:
# Unnamed: 0                                                                                                                                                                             int64
# name                                                                                                                                                                                  object
# artist                                                                                                                                                                                object
# danceability                                                                                                                                                                         float64
# energy                                                                                                                                                                               float64
# ...
